# %%
clean = open('_chat.txt','r+').read().replace('\n', ' ').replace('[', '\n')
#clean = clean.replace(']','/n')


#with open("converted.txt",'r+') as file:
#    file.truncate(0)
#    file.close()
file = open("converted.txt", "w")
am = file.write(clean)
file.close()

# %%
clean
# Out:
# '\n08/02/23, 3:58:37 PM] Top 1% Quality Engineers: \u200eMessages and calls are end-to-end encrypted. No one outside of this chat, not even WhatsApp, can read or listen to them. \n08/02/23, 3:58:37 PM] Ayush Poddar: \u200eAyush Poddar created this group \n09/02/23, 4:44:34 PM] Top 1% Quality Engineers: \u200eNaa.... added you \n09/02/23, 4:44:40 PM] Top 1% Quality Engineers: \u200eYou\'re now an admin \n09/02/23, 5:17:49 PM] Top 1% Quality Engineers: \u200eNaa.... added Amogh Lumen, Chiranth Tgt Mar 2023, and 43 others. Tap to see all. \n09/02/23, 5:18:35 PM] ~\u202f~Bhanu: \u200eNaa.... added ~\u202f~Bhanu \n09/02/23, 5:19:18 PM] ~\u202fHarikrishnan: Thanks Reine, \n09/02/23, 5:19:20 PM] ~\u202fHarikrishnan: Hello All. \n09/02/23, 5:19:37 PM] ~\u202fAmit Kumar Jha: Thanks Reine  Hello everyone \n09/02/23, 5:21:13 PM] Vivian Tgt Sales: Hi everyone, welcome to the Community of *Top 1% QA Professionals*...  Looking forward to supporting you in your career growth. \n09/02/23, 5:21:49 PM] Naa....: Hi, We are building a community of *"Top 1% of QA Engineers*". The entire idea is to enable QA engineers have the right growth awareness, build on their potential skills, get into their dream job and achieve highest packages in QA Vertical (which is 50L+). If you are interested to join our community, please click on the link below and join… https://chat.whatsapp.com/FHmw3F7qPWt3jAzKUOrUoF  We would also be encouraging interactions and  posting relevant content, articles, videos, scholarships, jobs, and hosting events from QA Leaders, Engineering Heads and Project Heads in the Community.  _Looking forward to see you there._ \n09/02/23, 5:22:24 PM] ~\u202fPraveen Singh V: Very warm welcome to all QA Professionals, this is Praveen Singh, xfounder of 99tests \n09/02/23, 5:23:09 PM] Naa....: Thanks everyone for joining. Trust everyone is doing well. Longtime! \n09/02/23, 5:23:22 PM] ~\u202fPraveen Singh V: Please feel free to ask any questions about building your career in QA \n09/02/23, 5:27:24 PM] Naa....: The next generation of applications are all driven by AI. This is an initiative to share skills and help you navigate the future and grow in your career. \n09/02/23, 5:28:35 PM] Naa....: The below are the facts that tell us we need powerful qa skills \n09/02/23, 5:28:38 PM] Naa....: https://www.linkedin.com/posts/reanzi_topgrep-chatgpt-fsqe-activity-7024781657001914368-p8hy?utm_source=share&utm_medium=member_ios \n09/02/23, 5:29:07 PM] Vivian Tgt Sales: Hi guys, my name is Vivian and I\'ll be your community manager here. So if there\'s anything y\'all want to know you can just ping me here and I\'ll help sort it out . 😊 \n09/02/23, 5:29:11 PM] Naa....: https://www.linkedin.com/posts/reanzi_google-shares-tank-after-chatgpt-rival-bard-activity-7029275358877163520-1vfU?utm_source=share&utm_medium=member_ios \n09/02/23, 5:30:15 PM] ~\u202fSyed Sulaiman Kareem: Thanks reine...This group is full of great test troopers... Looking forward to staying up to date with all the latest news.... \n09/02/23, 5:30:31 PM] Naa....: Please use this message to invite qa folks who you think would fit it here. \n09/02/23, 5:33:29 PM] ~\u202fChaitra Kumar: Thank you Reine. I am sure this group will really help us grow our career. \n09/02/23, 5:39:16 PM] Ayush Poddar: Hi everyone, This is Ayush. Looking forward to help this community achieve the vision of Top 0.1% QA Professionals from Top 1% QA Professionals... \n09/02/23, 5:39:32 PM] Ayush Poddar: Hi, We are building a community of *"Top 1% of QA Engineers*". The entire idea is to enable QA engineers have the right growth awareness, build on their potential skills, get into their dream job and achieve highest packages in QA Vertical (which is 50L+). If you are interested to join our community, please click on the link below and join… https://chat.whatsapp.com/FHmw3F7qPWt3jAzKUOrUoF  We would also be encouraging interactions and  posting relevant content, articles, videos, scholarships, jobs, and hosting events  ...

# %%
with open("converted.txt", 'r') as file:
  lines = file.readlines()

# %%
import pandas as pd
filename="converted.txt"
df=pd.read_csv(filename,header=None,error_bad_lines=False,encoding='utf8', sep = ']')

df
# Out:
# <ipython-input-240-6e142459e1c5>:3: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df=pd.read_csv(filename,header=None,error_bad_lines=False,encoding='utf8', sep = ']')
#                          0                                                  1
# 0     08/02/23, 3:58:37 PM   Top 1% Quality Engineers: ‎Messages and calls...
# 1     08/02/23, 3:58:37 PM    Ayush Poddar: ‎Ayush Poddar created this group
# 2     09/02/23, 4:44:34 PM      Top 1% Quality Engineers: ‎Naa.... added you
# 3     09/02/23, 4:44:40 PM    Top 1% Quality Engineers: ‎You're now an admin
# 4     09/02/23, 5:17:49 PM   Top 1% Quality Engineers: ‎Naa.... added Amog...
# ...                    ...                                                ...
# 3675  31/05/23, 1:58:17 PM   Naa....: Will share the emailid to the folks ...
# 3676  31/05/23, 2:00:53 PM                Naa....: Location: Bangalore, Pune
# 3677  31/05/23, 2:01:05 PM                    Naa....: Company: Epam systems
# 3678  31/05/23, 2:01:33 PM   Naa....: Just answering the qs tht people are...
# 3679  31/05/23, 2:47:42 PM   ‪+91 75077 78670‬: ‎‪+91 75077 78670‬ joined ...
#
# [3680 rows x 2 columns]

# %%
df[1145:]
# Out:
#                          0                                                  1
# 1145  08/03/23, 1:26:54 PM   ~ Vivian: Guys, We are organizing a free demo...
# 1146  08/03/23, 1:42:59 PM            ~ parshukobe841: ‎~ parshukobe841 left
# 1147  08/03/23, 1:53:40 PM   Top 1% Quality Engineers: ‎This group was add...
# 1148  08/03/23, 1:53:40 PM   Naa....: ‎Anyone in the community “Top .1% QE...
# 1149  08/03/23, 3:19:21 PM   Naa....: ‎Naa.... deactivated the community “...
# ...                    ...                                                ...
# 3675  31/05/23, 1:58:17 PM   Naa....: Will share the emailid to the folks ...
# 3676  31/05/23, 2:00:53 PM                Naa....: Location: Bangalore, Pune
# 3677  31/05/23, 2:01:05 PM                    Naa....: Company: Epam systems
# 3678  31/05/23, 2:01:33 PM   Naa....: Just answering the qs tht people are...
# 3679  31/05/23, 2:47:42 PM   ‪+91 75077 78670‬: ‎‪+91 75077 78670‬ joined ...
#
# [2535 rows x 2 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3680 entries, 0 to 3679
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       3680 non-null   object
#  1   1       3679 non-null   object
# dtypes: object(2)
# memory usage: 57.6+ KB

# %%
value1 = df.at[40, 1]
value1
# Out:
# " Vivian Tgt Sales: Hi guys, welcome to this group.  My name is Vivian and I'll be your community manager here. So if there's anything y'all want to know you can just ping me here and I'll help sort it out . 😊 "

# %%
df.columns=['Date', 'Chat']

# %%
Message= df['Chat'].str.split(":", n = 1, expand = True)

# %%
len(Message[0].unique())
# Out:
# 821

# %%
value110 = Message.at[47, 0]
val110 = Message.at[47, 1]
print(value110)
val110
# Out:
#  ‪+91 99458 25692‬
# ' \u200eNaa.... added \u202a+91\xa099458\xa025692\u202c '

# %%
date_time= df['Date'].str.split(",", n = 1, expand = True)
date_time
# Out:
#              0            1
# 0     08/02/23   3:58:37 PM
# 1     08/02/23   3:58:37 PM
# 2     09/02/23   4:44:34 PM
# 3     09/02/23   4:44:40 PM
# 4     09/02/23   5:17:49 PM
# ...        ...          ...
# 3675  31/05/23   1:58:17 PM
# 3676  31/05/23   2:00:53 PM
# 3677  31/05/23   2:01:05 PM
# 3678  31/05/23   2:01:33 PM
# 3679  31/05/23   2:47:42 PM
#
# [3680 rows x 2 columns]

# %%
final_df = pd.concat([date_time, Message], axis=1, join='inner')
final_df
# Out:
#              0            1                          0  \
# 0     08/02/23   3:58:37 PM   Top 1% Quality Engineers
# 1     08/02/23   3:58:37 PM               Ayush Poddar
# 2     09/02/23   4:44:34 PM   Top 1% Quality Engineers
# 3     09/02/23   4:44:40 PM   Top 1% Quality Engineers
# 4     09/02/23   5:17:49 PM   Top 1% Quality Engineers
# ...        ...          ...                        ...
# 3675  31/05/23   1:58:17 PM                    Naa....
# 3676  31/05/23   2:00:53 PM                    Naa....
# 3677  31/05/23   2:01:05 PM                    Naa....
# 3678  31/05/23   2:01:33 PM                    Naa....
# 3679  31/05/23   2:47:42 PM          ‪+91 75077 78670‬
#
#                                                       1
# 0      ‎Messages and calls are end-to-end encrypted....
# 1                     ‎Ayush Poddar created this group
# 2                                   ‎Naa.... added you
# 3                                 ‎You're now an admin
# 4      ‎Naa.... added Amogh Lumen, Chiranth Tgt Mar ...
# ...                                                 ...
# 3675   Will share the emailid to the folks who fit t...
# 3676                         Location: Bangalore, Pune
# 3677                             Company: Epam systems
# 3678   Just answering the qs tht people are pinging ...
# 3679   ‎‪+91 75077 78670‬ joined using this group's ...
#
# [3680 rows x 4 columns]

# %%
final_df.columns=['Date', 'Time', 'Member', 'Message']

# %%
final_df.head(50)
# Out:
#         Date          Time                           Member  \
# 0   08/02/23    3:58:37 PM         Top 1% Quality Engineers
# 1   08/02/23    3:58:37 PM                     Ayush Poddar
# 2   09/02/23    4:44:34 PM         Top 1% Quality Engineers
# 3   09/02/23    4:44:40 PM         Top 1% Quality Engineers
# 4   09/02/23    5:17:49 PM         Top 1% Quality Engineers
# 5   09/02/23    5:18:35 PM                         ~ ~Bhanu
# 6   09/02/23    5:19:18 PM                   ~ Harikrishnan
# 7   09/02/23    5:19:20 PM                   ~ Harikrishnan
# 8   09/02/23    5:19:37 PM                 ~ Amit Kumar Jha
# 9   09/02/23    5:21:13 PM                 Vivian Tgt Sales
# 10  09/02/23    5:21:49 PM                          Naa....
# 11  09/02/23    5:22:24 PM                ~ Praveen Singh V
# 12  09/02/23    5:23:09 PM                          Naa....
# 13  09/02/23    5:23:22 PM                ~ Praveen Singh V
# 14  09/02/23    5:27:24 PM                          Naa....
# 15  09/02/23    5:28:35 PM                          Naa....
# 16  09/02/23    5:28:38 PM                          Naa....
# 17  09/02/23    5:29:07 PM                 Vivian Tgt Sales
# 18  09/02/23    5:29:11 PM                          Naa....
# 19  09/02/23    5:30:15 PM           ~ Syed Sulaiman Kareem
# 20  09/02/23    5:30:31 PM                          Naa....
# 21  09/02/23    5:33:29 PM                  ~ Chaitra Kumar
# 22  09/02/23    5:39:16 PM                     Ayush Poddar
# 23  09/02/23    5:39:32 PM                     Ayush Poddar
# 24  09/02/23    5:39:57 PM                     Ayush Poddar
# 25  09/02/23    5:40:35 PM                ‪+91 88279 58539‬
# 26  09/02/23    5:43:18 PM                ~ Lakshmi Krishna
# 27  09/02/23    5:44:49 PM                    Ajith TopGrep
# 28  09/02/23    5:58:32 PM         Top 1% Quality Engineers
# 29  09/02/23    6:14:46 PM                     Ayush Poddar
# 30  09/02/23    6:16:49 PM                 Vivian Tgt Sales
# 31  09/02/23    6:26:05 PM                    ~ Harshitha K
# 32  09/02/23    6:29:56 PM                        ~ twinkle
# 33  09/02/23    6:30:48 PM              ~ Krishna Chaitanya
# 34  09/02/23    6:31:41 PM                         ~ Pari 😇
# 35  09/02/23    6:39:21 PM            Chiranth Tgt Mar 2023
# 36  09/02/23    6:40:44 PM                     Ayush Poddar
# 37  09/02/23    6:42:52 PM                    ~ Kiran Naidu
# 38  09/02/23    6:50:47 PM         Top 1% Quality Engineers
# 39  09/02/23    6:52:59 PM                     Ayush Poddar
# 40  09/02/23    6:53:37 PM                 Vivian Tgt Sales
# 41  09/02/23    6:55:23 PM                        ~ Shruthi
# 42  09/02/23    7:13:00 PM                    ~ Soham Patel
# 43  09/02/23    7:14:28 PM   Santhosh Voruganti Tgt Student
# 44  09/02/23    7:05:20 PM                     Ayush Poddar
# 45  09/02/23    8:15:58 PM                       ~ Ssivanna
# 46  09/02/23    8:35:09 PM                        ~ Mamatha
# 47  09/02/23    9:32:23 PM                ‪+91 99458 25692‬
# 48  09/02/23   10:53:02 PM                Nagesh Eraiah Ctl
# 49  09/02/23   10:46:59 PM                ~ Subhajit Thakur
#
#                                               Message
# 0    ‎Messages and calls are end-to-end encrypted....
# 1                   ‎Ayush Poddar created this group
# 2                                 ‎Naa.... added you
# 3                               ‎You're now an admin
# 4    ‎Naa.... added Amogh Lumen, Chiranth Tgt Mar ...
# 5                            ‎Naa.... added ~ ~Bhanu
# 6                                      Thanks Reine,
# 7                                         Hello All.
# 8                       Thanks Reine  Hello everyone
# 9    Hi everyone, welcome to the Community of *Top...
# 10   Hi, We are building a community of *"Top 1% o...
# 11   Very warm welcome to all QA Professionals, th...
# 12   Thanks everyone for joining. Trust everyone i...
# 13   Please feel free to ask any questions about b...
# 14   The next generation of applications are all d...
# 15   The below are the facts that tell us we need ...
# 16   https://www.linkedin.com/posts/reanzi_topgrep...
# 17   Hi guys, my name is Vivian and I'll be your c...
# 18   https://www.linkedin.com/posts/reanzi_google-...
# 19   Thanks reine...This group is full of great te...
# 20   Please use this message to invite qa folks wh...
# 21   Thank you Reine. I am sure this group will re...
# 22   Hi everyone, This is Ayush. Looking forward t...
# 23   Hi, We are building a community of *"Top 1% o...
# 24   Please invite your friends, colleagues and pe...
# 25   ‎‪+91 88279 58539‬ joined using this group's ...
# 26          Hi everyone, thanks for adding us Reine.
# 27   ‎Ajith TopGrep joined using this group's invi...
# 28   ‎You added Abhinand Ibm, Bala Porala Lumen, a...
# 29                                Welcome everyone 🙂
# 30   Hi guys, welcome.    My name is Vivian and I'...
# 31   Hi Everyone..  Looking forward to a lot of le...
# 32                           Thank you @919449031578
# 33   Thank you @919449031578 for adding us. Hoping...
# 34   Hello everyone.. Thank you for adding us @919...
# 35   Hello everyone, good to know all of you, look...
# 36   Dr. Reine @919449031578  has been an inspirat...
# 37   Great initiative @919449031578 👍🏼looking forw...
# 38   ‎You added Ashik Ctli, Basawaraj Tonshalli Lu...
# 39   Welcome everyone to this amazing community of...
# 40   Hi guys, welcome to this group.  My name is V...
# 41   ‎~ Shruthi joined using this group's invite l...
# 42                      ‎Naa.... added ~ Soham Patel
# 43     ‎Naa.... added Santhosh Voruganti Tgt Student
# 44   Hi @919901355638 ,  Welcome to the community ...
# 45   Hello everyone, Hi  @Dr Reine Good to see in ...
# 46                    Hello everyone Thank you Reine
# 47                  ‎Naa.... added ‪+91 99458 25692‬
# 48                           ‎Nagesh Eraiah Ctl left
# 49   Hello Everyone, we should have fews developer...

# %%
final_df_for_count = final_df.copy()

# %%
all_left = []
lennn=[]

for num in range(len(final_df_for_count)):
  ax=final_df_for_count['Member'][num:num+1]
  txt=ax.item()
  try:
    x = txt.find("left")
    if x != -1:
      lennn.append(num)
      final_df_for_count['Member'][num:num+1] = txt.replace(' left', '')
  except:
    print()

# %%
lennn
# Out:
# []

# %%
final_df_copy=final_df.copy()

# %%
final_df_copy['Message'].isna().sum()
# Out:
# 4

# %%
final_df_copy=final_df_copy.dropna()
final_df_copy = final_df_copy.reset_index()
final_df_copy=final_df_copy.drop(columns='index')
final_df_copy['Message'].isna().sum()
# Out:
# 0

# %%
final_df_copy.head(50)
# Out:
#         Date          Time                           Member  \
# 0   08/02/23    3:58:37 PM         Top 1% Quality Engineers
# 1   08/02/23    3:58:37 PM                     Ayush Poddar
# 2   09/02/23    4:44:34 PM         Top 1% Quality Engineers
# 3   09/02/23    4:44:40 PM         Top 1% Quality Engineers
# 4   09/02/23    5:17:49 PM         Top 1% Quality Engineers
# 5   09/02/23    5:18:35 PM                         ~ ~Bhanu
# 6   09/02/23    5:19:18 PM                   ~ Harikrishnan
# 7   09/02/23    5:19:20 PM                   ~ Harikrishnan
# 8   09/02/23    5:19:37 PM                 ~ Amit Kumar Jha
# 9   09/02/23    5:21:13 PM                 Vivian Tgt Sales
# 10  09/02/23    5:21:49 PM                          Naa....
# 11  09/02/23    5:22:24 PM                ~ Praveen Singh V
# 12  09/02/23    5:23:09 PM                          Naa....
# 13  09/02/23    5:23:22 PM                ~ Praveen Singh V
# 14  09/02/23    5:27:24 PM                          Naa....
# 15  09/02/23    5:28:35 PM                          Naa....
# 16  09/02/23    5:28:38 PM                          Naa....
# 17  09/02/23    5:29:07 PM                 Vivian Tgt Sales
# 18  09/02/23    5:29:11 PM                          Naa....
# 19  09/02/23    5:30:15 PM           ~ Syed Sulaiman Kareem
# 20  09/02/23    5:30:31 PM                          Naa....
# 21  09/02/23    5:33:29 PM                  ~ Chaitra Kumar
# 22  09/02/23    5:39:16 PM                     Ayush Poddar
# 23  09/02/23    5:39:32 PM                     Ayush Poddar
# 24  09/02/23    5:39:57 PM                     Ayush Poddar
# 25  09/02/23    5:40:35 PM                ‪+91 88279 58539‬
# 26  09/02/23    5:43:18 PM                ~ Lakshmi Krishna
# 27  09/02/23    5:44:49 PM                    Ajith TopGrep
# 28  09/02/23    5:58:32 PM         Top 1% Quality Engineers
# 29  09/02/23    6:14:46 PM                     Ayush Poddar
# 30  09/02/23    6:16:49 PM                 Vivian Tgt Sales
# 31  09/02/23    6:26:05 PM                    ~ Harshitha K
# 32  09/02/23    6:29:56 PM                        ~ twinkle
# 33  09/02/23    6:30:48 PM              ~ Krishna Chaitanya
# 34  09/02/23    6:31:41 PM                         ~ Pari 😇
# 35  09/02/23    6:39:21 PM            Chiranth Tgt Mar 2023
# 36  09/02/23    6:40:44 PM                     Ayush Poddar
# 37  09/02/23    6:42:52 PM                    ~ Kiran Naidu
# 38  09/02/23    6:50:47 PM         Top 1% Quality Engineers
# 39  09/02/23    6:52:59 PM                     Ayush Poddar
# 40  09/02/23    6:53:37 PM                 Vivian Tgt Sales
# 41  09/02/23    6:55:23 PM                        ~ Shruthi
# 42  09/02/23    7:13:00 PM                    ~ Soham Patel
# 43  09/02/23    7:14:28 PM   Santhosh Voruganti Tgt Student
# 44  09/02/23    7:05:20 PM                     Ayush Poddar
# 45  09/02/23    8:15:58 PM                       ~ Ssivanna
# 46  09/02/23    8:35:09 PM                        ~ Mamatha
# 47  09/02/23    9:32:23 PM                ‪+91 99458 25692‬
# 48  09/02/23   10:53:02 PM                Nagesh Eraiah Ctl
# 49  09/02/23   10:46:59 PM                ~ Subhajit Thakur
#
#                                               Message
# 0    ‎Messages and calls are end-to-end encrypted....
# 1                   ‎Ayush Poddar created this group
# 2                                 ‎Naa.... added you
# 3                               ‎You're now an admin
# 4    ‎Naa.... added Amogh Lumen, Chiranth Tgt Mar ...
# 5                            ‎Naa.... added ~ ~Bhanu
# 6                                      Thanks Reine,
# 7                                         Hello All.
# 8                       Thanks Reine  Hello everyone
# 9    Hi everyone, welcome to the Community of *Top...
# 10   Hi, We are building a community of *"Top 1% o...
# 11   Very warm welcome to all QA Professionals, th...
# 12   Thanks everyone for joining. Trust everyone i...
# 13   Please feel free to ask any questions about b...
# 14   The next generation of applications are all d...
# 15   The below are the facts that tell us we need ...
# 16   https://www.linkedin.com/posts/reanzi_topgrep...
# 17   Hi guys, my name is Vivian and I'll be your c...
# 18   https://www.linkedin.com/posts/reanzi_google-...
# 19   Thanks reine...This group is full of great te...
# 20   Please use this message to invite qa folks wh...
# 21   Thank you Reine. I am sure this group will re...
# 22   Hi everyone, This is Ayush. Looking forward t...
# 23   Hi, We are building a community of *"Top 1% o...
# 24   Please invite your friends, colleagues and pe...
# 25   ‎‪+91 88279 58539‬ joined using this group's ...
# 26          Hi everyone, thanks for adding us Reine.
# 27   ‎Ajith TopGrep joined using this group's invi...
# 28   ‎You added Abhinand Ibm, Bala Porala Lumen, a...
# 29                                Welcome everyone 🙂
# 30   Hi guys, welcome.    My name is Vivian and I'...
# 31   Hi Everyone..  Looking forward to a lot of le...
# 32                           Thank you @919449031578
# 33   Thank you @919449031578 for adding us. Hoping...
# 34   Hello everyone.. Thank you for adding us @919...
# 35   Hello everyone, good to know all of you, look...
# 36   Dr. Reine @919449031578  has been an inspirat...
# 37   Great initiative @919449031578 👍🏼looking forw...
# 38   ‎You added Ashik Ctli, Basawaraj Tonshalli Lu...
# 39   Welcome everyone to this amazing community of...
# 40   Hi guys, welcome to this group.  My name is V...
# 41   ‎~ Shruthi joined using this group's invite l...
# 42                      ‎Naa.... added ~ Soham Patel
# 43     ‎Naa.... added Santhosh Voruganti Tgt Student
# 44   Hi @919901355638 ,  Welcome to the community ...
# 45   Hello everyone, Hi  @Dr Reine Good to see in ...
# 46                    Hello everyone Thank you Reine
# 47                  ‎Naa.... added ‪+91 99458 25692‬
# 48                           ‎Nagesh Eraiah Ctl left
# 49   Hello Everyone, we should have fews developer...

# %%
len(final_df_copy)
# Out:
# 3676

# %%
all_poll = pd.DataFrame(columns=['poll'])
all_poll_member_name = pd.DataFrame(columns=['name'])
for num in range(len(final_df_copy)):
  ax=final_df_copy['Message'][num:num+1]
  txt=ax.item()
  if txt != None:
    x = txt.find("POLL:")
    if x != -1:
      all_poll.loc[len(all_poll)] = txt
      all_poll_member_name.loc[len(all_poll_member_name)] = final_df_copy['Member'][num:num+1].item()

all_poll
# Out:
#                                                  poll
# 0    ‎POLL: Test coverage is ‎OPTION: The build te...
# 1    ‎POLL: Can a consumer also act as a producer ...
# 2    ‎POLL: Orthogonal defect classification is do...
# 3    ‎POLL: Test Effectiveness ‎OPTION: Number of ...
# 4    ‎POLL: Test data generation ‎OPTION: Real set...
# 5    ‎POLL: Use data-driven testing ‎OPTION: Appli...
# 6    ‎POLL: Test coverage helps to ‎OPTION: Correc...
# 7    ‎POLL: How many of you feel that having a gre...
# 8    ‎POLL: I want to become a quality engineer be...
# 9    ‎POLL: Freshers skills not up to mark ‎OPTION...
# 10   ‎POLL: How do you prepare for interview quest...
# 11   ‎POLL: What are the general myths that you he...
# 12   ‎POLL: What do you want us to cover in today'...
# 13   ‎POLL: How do you write/decide regression tes...
# 14   ‎POLL: What should be our next event topic? ‎...
# 15   ‎POLL: Good Morning everyone, What's your pri...
# 16   ‎POLL: Which time is suitable for our event *...
# 17   ‎POLL: Hello everyone, Hope you have attended...
# 18   ‎POLL: Hello everyone, It seems most of you h...
# 19   ‎POLL: Guys, We have significant queries on h...

# %%
all_poll_member_name
# Out:
#                   name
# 0                Hemmy
# 1              Naa....
# 2                Hemmy
# 3                Hemmy
# 4                Hemmy
# 5                Hemmy
# 6                Hemmy
# 7         Ayush Poddar
# 8              Naa....
# 9    ~ Praveen Singh V
# 10        Ayush Poddar
# 11        Ayush Poddar
# 12        Ayush Poddar
# 13       ~ Soham Patel
# 14        Ayush Poddar
# 15        Ayush Poddar
# 16        Ayush Poddar
# 17        Ayush Poddar
# 18        Ayush Poddar
# 19        Ayush Poddar

# %%
latest_poll = pd.DataFrame(columns=['poll'])
latest_poll_member_name = pd.DataFrame(columns=['name'])

for x in range(1,6):
  latest_poll.loc[len(latest_poll)] = all_poll.iloc[-x].item().replace('‎OPTION:', ':')
  latest_poll_member_name.loc[len(latest_poll_member_name)] = all_poll_member_name.iloc[-x].item()

latest_poll= latest_poll['poll'].str.split(" ‎POLL: ", n = 1, expand = True)
latest_poll=latest_poll.drop(columns=0)

# %%
latest_poll_member_name
# Out:
#             name
# 0   Ayush Poddar
# 1   Ayush Poddar
# 2   Ayush Poddar
# 3   Ayush Poddar
# 4   Ayush Poddar

# %%
latest_poll.columns=['Question']
latest_poll
# Out:
#                                             Question
# 0  Guys, We have significant queries on how to up...
# 1  Hello everyone, It seems most of you have miss...
# 2  Hello everyone, Hope you have attended and enj...
# 3  Which time is suitable for our event *QA / QE ...
# 4  Good Morning everyone, What's your priority fo...

# %%
latest_poll= latest_poll['Question'].str.split(" : ", expand = True)

# %%
latest_poll
# Out:
#                                                    0  \
# 0  Guys, We have significant queries on how to up...
# 1  Hello everyone, It seems most of you have miss...
# 2  Hello everyone, Hope you have attended and enj...
# 3  Which time is suitable for our event *QA / QE ...
# 4  Good Morning everyone, What's your priority fo...
#
#                                                    1  \
# 0                                 ChatGPT (44 votes)
# 1                             Yes, I'm in (21 votes)
# 2  Event Attended and Counselling Form filled (4 ...
# 3  Counseling event for Job Search and Skill Upgr...
# 4                              Job Search (50 votes)
#
#                                                    2  \
# 0                                  CoPilot (5 votes)
# 1             Interested but not available (5 votes)
# 2  Event Attended and haven't filled counselling ...
# 3                                  8:00 PM (2 votes)
# 4                                Learning (40 votes)
#
#                                3                                        4  \
# 0          Boilerplates (1 vote)                          LLMs (7 votes)
# 1  I'm not interested (4 votes)                                      None
# 2  Not attended Event (11 votes)  Want to fill counselling form (1 vote)
# 3             8:30 PM (15 votes)                        7:30 PM (3 votes)
# 4    Project Delivery (11 votes)    Fun with Friends and Family (4 votes)
#
#                                       5
# 0                                  None
# 1                                  None
# 2                                  None
# 3                    Anytime (4 votes)
# 4  Figuring out what's next (10 votes)

# %%
lis=['Question']

for n in range(1,len(latest_poll.columns)):
  n='Option'+str(n)
  lis.append(n)

# %%
latest_poll.columns=[lis]
latest_poll.fillna("N/A", inplace = True)
print(latest_poll.to_markdown())
# Out:
# |    | ('Question',)                                                                                                                                                                                                                                                   | ('Option1',)                                         | ('Option2',)                                                | ('Option3',)                  | ('Option4',)                           | ('Option5',)                        |
# |---:|:----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|:-----------------------------------------------------|:------------------------------------------------------------|:------------------------------|:---------------------------------------|:------------------------------------|
# |  0 | Guys, We have significant queries on how to upgrade ourselves in the evolving technological times. We need to understand your interest before planning any event to address the same.  What would you like to learn with respect to Quality Engineering KRAs?   | ChatGPT (44 votes)                                   | CoPilot (5 votes)                                           | Boilerplates (1 vote)         | LLMs (7 votes)                         | N/A                                 |
# |  1 | Hello everyone, It seems most of you have missed our event today on *"Elevating from QA Manager Role to QE Leader Role"* ...  Would you like us to organise this event again on Monday 8 PM? Will you join if we plan?  Pls cast your vote and help us decide.. | Yes, I'm in (21 votes)                               | Interested but not available (5 votes)                      | I'm not interested (4 votes)  | N/A                                    | N/A                                 |
# |  2 | Hello everyone, Hope you have attended and enjoyed yesterday's QA / QE counseling event... We have also shared 1:1 counselling form in the event. Let us know your inputs from the following...                                                                 | Event Attended and Counselling Form filled (4 votes) | Event Attended and haven't filled counselling form (1 vote) | Not attended Event (11 votes) | Want to fill counselling form (1 vote) | N/A                                 |
# |  3 | Which time is suitable for our event *QA / QE Career Boost                                                                                                                                                                                                      | Counseling event for Job Search and Skill Upgrades*  | 8:00 PM (2 votes)                                           | 8:30 PM (15 votes)            | 7:30 PM (3 votes)                      | Anytime (4 votes)                   |
# |  4 | Good Morning everyone, What's your priority for this week?                                                                                                                                                                                                      | Job Search (50 votes)                                | Learning (40 votes)                                         | Project Delivery (11 votes)   | Fun with Friends and Family (4 votes)  | Figuring out what's next (10 votes) |

# %%
latest_poll
# Out:
#                                             Question  \
# 0  Guys, We have significant queries on how to up...
# 1  Hello everyone, It seems most of you have miss...
# 2  Hello everyone, Hope you have attended and enj...
# 3  Which time is suitable for our event *QA / QE ...
# 4  Good Morning everyone, What's your priority fo...
#
#                                              Option1  \
# 0                                 ChatGPT (44 votes)
# 1                             Yes, I'm in (21 votes)
# 2  Event Attended and Counselling Form filled (4 ...
# 3  Counseling event for Job Search and Skill Upgr...
# 4                              Job Search (50 votes)
#
#                                              Option2  \
# 0                                  CoPilot (5 votes)
# 1             Interested but not available (5 votes)
# 2  Event Attended and haven't filled counselling ...
# 3                                  8:00 PM (2 votes)
# 4                                Learning (40 votes)
#
#                          Option3                                  Option4  \
# 0          Boilerplates (1 vote)                          LLMs (7 votes)
# 1  I'm not interested (4 votes)                                       N/A
# 2  Not attended Event (11 votes)  Want to fill counselling form (1 vote)
# 3             8:30 PM (15 votes)                        7:30 PM (3 votes)
# 4    Project Delivery (11 votes)    Fun with Friends and Family (4 votes)
#
#                                 Option5
# 0                                   N/A
# 1                                   N/A
# 2                                   N/A
# 3                    Anytime (4 votes)
# 4  Figuring out what's next (10 votes)

# %%
fianl_poll = pd.concat([latest_poll_member_name, latest_poll], axis=1)
fianl_poll
# Out:
#             name                                        (Question,)  \
# 0   Ayush Poddar  Guys, We have significant queries on how to up...
# 1   Ayush Poddar  Hello everyone, It seems most of you have miss...
# 2   Ayush Poddar  Hello everyone, Hope you have attended and enj...
# 3   Ayush Poddar  Which time is suitable for our event *QA / QE ...
# 4   Ayush Poddar  Good Morning everyone, What's your priority fo...
#
#                                           (Option1,)  \
# 0                                 ChatGPT (44 votes)
# 1                             Yes, I'm in (21 votes)
# 2  Event Attended and Counselling Form filled (4 ...
# 3  Counseling event for Job Search and Skill Upgr...
# 4                              Job Search (50 votes)
#
#                                           (Option2,)  \
# 0                                  CoPilot (5 votes)
# 1             Interested but not available (5 votes)
# 2  Event Attended and haven't filled counselling ...
# 3                                  8:00 PM (2 votes)
# 4                                Learning (40 votes)
#
#                       (Option3,)                               (Option4,)  \
# 0          Boilerplates (1 vote)                          LLMs (7 votes)
# 1  I'm not interested (4 votes)                                       N/A
# 2  Not attended Event (11 votes)  Want to fill counselling form (1 vote)
# 3             8:30 PM (15 votes)                        7:30 PM (3 votes)
# 4    Project Delivery (11 votes)    Fun with Friends and Family (4 votes)
#
#                              (Option5,)
# 0                                   N/A
# 1                                   N/A
# 2                                   N/A
# 3                    Anytime (4 votes)
# 4  Figuring out what's next (10 votes)

# %%
array_temp=[]
for del_poll in range(len(all_poll)):
  poll_to_be_del=all_poll['poll'][del_poll:del_poll+1].item()
  for temp in range(len(final_df_copy)):
    searching=final_df_copy['Message'][temp:temp+1].item()
    if searching == poll_to_be_del:
      array_temp.append(temp)

# %%
array_temp
# Out:
# [65,
#  185,
#  194,
#  249,
#  365,
#  484,
#  624,
#  791,
#  995,
#  1059,
#  1173,
#  1530,
#  1578,
#  2042,
#  2102,
#  2773,
#  2784,
#  2839,
#  3164,
#  3617]

# %%
clean_df=final_df_copy.copy()

# %%
clean_df.drop(array_temp, inplace=True)
clean_df = clean_df.reset_index()
clean_df=clean_df.drop(columns='index')

# %%
all_deleted = []

for num in range(len(clean_df)):
  ax=clean_df['Message'][num:num+1]
  txt=ax.item()
  if txt != None:
    x = txt.find("deleted")
    if x != -1:
      all_deleted.append(num)

# %%
clean_df.drop(all_deleted, inplace=True)
clean_df = clean_df.reset_index()
clean_df=clean_df.drop(columns='index')
clean_df
# Out:
#           Date         Time                     Member  \
# 0     08/02/23   3:58:37 PM   Top 1% Quality Engineers
# 1     08/02/23   3:58:37 PM               Ayush Poddar
# 2     09/02/23   4:44:34 PM   Top 1% Quality Engineers
# 3     09/02/23   4:44:40 PM   Top 1% Quality Engineers
# 4     09/02/23   5:17:49 PM   Top 1% Quality Engineers
# ...        ...          ...                        ...
# 3515  31/05/23   1:58:17 PM                    Naa....
# 3516  31/05/23   2:00:53 PM                    Naa....
# 3517  31/05/23   2:01:05 PM                    Naa....
# 3518  31/05/23   2:01:33 PM                    Naa....
# 3519  31/05/23   2:47:42 PM          ‪+91 75077 78670‬
#
#                                                 Message
# 0      ‎Messages and calls are end-to-end encrypted....
# 1                     ‎Ayush Poddar created this group
# 2                                   ‎Naa.... added you
# 3                                 ‎You're now an admin
# 4      ‎Naa.... added Amogh Lumen, Chiranth Tgt Mar ...
# ...                                                 ...
# 3515   Will share the emailid to the folks who fit t...
# 3516                         Location: Bangalore, Pune
# 3517                             Company: Epam systems
# 3518   Just answering the qs tht people are pinging ...
# 3519   ‎‪+91 75077 78670‬ joined using this group's ...
#
# [3520 rows x 4 columns]

# %%
all_omitted = []

for num in range(len(clean_df)):
  ax=clean_df['Message'][num:num+1]
  txt=ax.item()
  if txt != None:
    x = txt.find("omitted")
    if x != -1:
      all_omitted.append(num)

# %%
clean_df.drop(all_omitted, inplace=True)
clean_df = clean_df.reset_index()
clean_df=clean_df.drop(columns='index')
clean_df
# Out:
#           Date         Time                     Member  \
# 0     08/02/23   3:58:37 PM   Top 1% Quality Engineers
# 1     08/02/23   3:58:37 PM               Ayush Poddar
# 2     09/02/23   4:44:34 PM   Top 1% Quality Engineers
# 3     09/02/23   4:44:40 PM   Top 1% Quality Engineers
# 4     09/02/23   5:17:49 PM   Top 1% Quality Engineers
# ...        ...          ...                        ...
# 3462  31/05/23   1:58:17 PM                    Naa....
# 3463  31/05/23   2:00:53 PM                    Naa....
# 3464  31/05/23   2:01:05 PM                    Naa....
# 3465  31/05/23   2:01:33 PM                    Naa....
# 3466  31/05/23   2:47:42 PM          ‪+91 75077 78670‬
#
#                                                 Message
# 0      ‎Messages and calls are end-to-end encrypted....
# 1                     ‎Ayush Poddar created this group
# 2                                   ‎Naa.... added you
# 3                                 ‎You're now an admin
# 4      ‎Naa.... added Amogh Lumen, Chiranth Tgt Mar ...
# ...                                                 ...
# 3462   Will share the emailid to the folks who fit t...
# 3463                         Location: Bangalore, Pune
# 3464                             Company: Epam systems
# 3465   Just answering the qs tht people are pinging ...
# 3466   ‎‪+91 75077 78670‬ joined using this group's ...
#
# [3467 rows x 4 columns]

# %%
clean_df.to_csv("clean_df")

# %%
from wordcloud import WordCloud
from wordcloud import ImageColorGenerator
from wordcloud import STOPWORDS
import matplotlib.pyplot as plt
import pandas as pd

# %%
text = " ".join(i for i in clean_df['Message'])
stopwords = set(STOPWORDS)
wordcloud = WordCloud(stopwords=stopwords, background_color="white").generate(text)
plt.figure( figsize=(11,10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()
#plt.savefig('wordcloud.pdf')
wordcloud.to_file('wordcloud.png')

# %%
text = " ".join(i for i in clean_df['Message'])
#stopwords = set(STOPWORDS)
wordcloud = WordCloud(width=1600, height=800).generate(text)
plt.figure( figsize=(20,10), facecolor='k')
plt.imshow(wordcloud)
plt.axis("off")
plt.savefig('wordcloud.png', facecolor='k', bbox_inches='tight')
#plt.tight_layout(pad=0)
plt.show()
#plt.savefig('wordcloud.pdf')
#wordcloud.to_file('wordcloud.png')
plt.clf()

# %%
clean_df['Message'].count()
# Out:
# 3467

# %%
top10df = clean_df.groupby("Member")["Message"].count().sort_values(ascending=False)
top10df = top10df.head(10).reset_index()
top10df
# Out:
#                         Member  Message
# 0                 Ayush Poddar      675
# 1                      Naa....      208
# 2   ~ Live A LIFE You Remember      134
# 3               ~ raveendraiah       54
# 4                      ~ Bilal       45
# 5                 ~ Zero Floor       44
# 6                        Hemmy       43
# 7                       ~ Mona       37
# 8            ~ Partha Mandayam       33
# 9               ~ Sunil Bansal       22

# %%
top10df['Message']
# Out:
# 0    675
# 1    208
# 2    134
# 3     54
# 4     45
# 5     44
# 6     43
# 7     37
# 8     33
# 9     22
# Name: Message, dtype: int64

# %%
import seaborn as sns
import matplotlib

sns.set_style("darkgrid")
matplotlib.rcParams['figure.figsize'] = (12, 10)

# A bar plot for top 10 days
sns.barplot(x=top10df.Member, y=top10df.Message, palette="CMRmap",dodge=False).set_xticklabels(rotation=50, labels=top10df.Member)
plt.ylabel("no. of messages")
#plt.show()
plt.savefig('most_active.png')
# Saving the plots
#plt.savefig('top10_days.svg', format = 'svg')

# %%
clean_df
# Out:
#           Date         Time                     Member  \
# 0     08/02/23   3:58:37 PM   Top 1% Quality Engineers
# 1     08/02/23   3:58:37 PM               Ayush Poddar
# 2     09/02/23   4:44:34 PM   Top 1% Quality Engineers
# 3     09/02/23   4:44:40 PM   Top 1% Quality Engineers
# 4     09/02/23   5:17:49 PM   Top 1% Quality Engineers
# ...        ...          ...                        ...
# 3462  31/05/23   1:58:17 PM                    Naa....
# 3463  31/05/23   2:00:53 PM                    Naa....
# 3464  31/05/23   2:01:05 PM                    Naa....
# 3465  31/05/23   2:01:33 PM                    Naa....
# 3466  31/05/23   2:47:42 PM          ‪+91 75077 78670‬
#
#                                                 Message
# 0      ‎Messages and calls are end-to-end encrypted....
# 1                     ‎Ayush Poddar created this group
# 2                                   ‎Naa.... added you
# 3                                 ‎You're now an admin
# 4      ‎Naa.... added Amogh Lumen, Chiranth Tgt Mar ...
# ...                                                 ...
# 3462   Will share the emailid to the folks who fit t...
# 3463                         Location: Bangalore, Pune
# 3464                             Company: Epam systems
# 3465   Just answering the qs tht people are pinging ...
# 3466   ‎‪+91 75077 78670‬ joined using this group's ...
#
# [3467 rows x 4 columns]

# %%
from datetime import datetime
drop_ind=[]
def check_datetime_format(datetime_str, format_str):
    try:
        datetime.strptime(datetime_str, format_str)
        return True
    except ValueError:
        return False
for xx in range (len(clean_df)):
  date_string = clean_df['Date'][xx:xx+1].item()

  if check_datetime_format(date_string, "%d/%m/%y"):
    x=0
  else:
    print("Date format is incorrect")
    drop_ind.append(xx)
# Out:
# Date format is incorrect
# Date format is incorrect
# Date format is incorrect
# Date format is incorrect
# Date format is incorrect

# %%
drop_ind
# Out:
# [3103, 3104, 3105, 3106, 3107]

# %%
clean_df.drop(drop_ind, inplace=True)
clean_df = clean_df.reset_index()
clean_df=clean_df.drop(columns='index')

# %%
from datetime import datetime, date
clean_df.Date = clean_df.Date.apply(lambda x: datetime.strptime(x, '%d/%m/%y'))
clean_df['day'] = clean_df.Date.apply(lambda x: x.strftime('%A'))
clean_df['month'] = clean_df.Date.apply(lambda x: x.strftime('%B'))
clean_df['year'] = clean_df.Date.apply(lambda x: x.strftime('%Y'))

# %%
clean_df_copy=clean_df.copy()

# %%
for i in range(clean_df.shape[0]):
    if clean_df.Time[i][-2:].strip(' ') == 'AM':
        if clean_df.Time[i][:3].strip(' ') == '12':
            clean_df.Time[i] = '00' + clean_df.Time[i][3:-6]
            clean_df.Time[i] = clean_df.Time[i].strip(' ')
        else:
            clean_df.Time[i] = clean_df.Time[i][:-6].strip(' ')
    else:
        if clean_df.Time[i][:3].strip(' ') == '12':
            clean_df.Time[i] = clean_df.Time[i][:-6].strip(' ')
        else:
            clean_df.Time[i] = str(int(clean_df.Time[i][:-9]) + 12) + clean_df.Time[i][-9:-6]
            clean_df.Time[i] = clean_df.Time[i].strip(' ')
# Out:
# <ipython-input-293-22e513dd2544>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_df.Time[i] = str(int(clean_df.Time[i][:-9]) + 12) + clean_df.Time[i][-9:-6]
# <ipython-input-293-22e513dd2544>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_df.Time[i] = clean_df.Time[i].strip(' ')
# <ipython-input-293-22e513dd2544>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_df.Time[i] = clean_df.Time[i][:-6].strip(' ')
# <ipython-input-293-22e513dd2544>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_df.Time[i] = clean_df.Time[i][:-6].strip(' ')
# <ipython-input-293-22e513dd2544>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_df.Time[i] = '00' + clean_df.Time[i][3:-6]
# <ipython-input-293-22e513dd2544>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_df.Time[i] = clean_df.Time[i].strip(' ')

# %%
clean_df
# Out:
#            Date   Time                     Member  \
# 0    2023-02-08  15:58   Top 1% Quality Engineers
# 1    2023-02-08  15:58               Ayush Poddar
# 2    2023-02-09  16:44   Top 1% Quality Engineers
# 3    2023-02-09  16:44   Top 1% Quality Engineers
# 4    2023-02-09  17:17   Top 1% Quality Engineers
# ...         ...    ...                        ...
# 3457 2023-05-31  13:58                    Naa....
# 3458 2023-05-31  14:00                    Naa....
# 3459 2023-05-31  14:01                    Naa....
# 3460 2023-05-31  14:01                    Naa....
# 3461 2023-05-31  14:47          ‪+91 75077 78670‬
#
#                                                 Message        day     month  \
# 0      ‎Messages and calls are end-to-end encrypted....  Wednesday  February
# 1                     ‎Ayush Poddar created this group   Wednesday  February
# 2                                   ‎Naa.... added you    Thursday  February
# 3                                 ‎You're now an admin    Thursday  February
# 4      ‎Naa.... added Amogh Lumen, Chiranth Tgt Mar ...   Thursday  February
# ...                                                 ...        ...       ...
# 3457   Will share the emailid to the folks who fit t...  Wednesday       May
# 3458                         Location: Bangalore, Pune   Wednesday       May
# 3459                             Company: Epam systems   Wednesday       May
# 3460   Just answering the qs tht people are pinging ...  Wednesday       May
# 3461   ‎‪+91 75077 78670‬ joined using this group's ...  Wednesday       May
#
#       year
# 0     2023
# 1     2023
# 2     2023
# 3     2023
# 4     2023
# ...    ...
# 3457  2023
# 3458  2023
# 3459  2023
# 3460  2023
# 3461  2023
#
# [3462 rows x 7 columns]

# %%
clean_df['hour'] = 0

# %%
for i in range(clean_df.shape[0]):
  clean_df.hour[i] = clean_df.Time[i][:-3]
# Out:
# <ipython-input-296-7c20b3de4b8d>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_df.hour[i] = clean_df.Time[i][:-3]

# %%
clean_df
# Out:
#            Date   Time                     Member  \
# 0    2023-02-08  15:58   Top 1% Quality Engineers
# 1    2023-02-08  15:58               Ayush Poddar
# 2    2023-02-09  16:44   Top 1% Quality Engineers
# 3    2023-02-09  16:44   Top 1% Quality Engineers
# 4    2023-02-09  17:17   Top 1% Quality Engineers
# ...         ...    ...                        ...
# 3457 2023-05-31  13:58                    Naa....
# 3458 2023-05-31  14:00                    Naa....
# 3459 2023-05-31  14:01                    Naa....
# 3460 2023-05-31  14:01                    Naa....
# 3461 2023-05-31  14:47          ‪+91 75077 78670‬
#
#                                                 Message        day     month  \
# 0      ‎Messages and calls are end-to-end encrypted....  Wednesday  February
# 1                     ‎Ayush Poddar created this group   Wednesday  February
# 2                                   ‎Naa.... added you    Thursday  February
# 3                                 ‎You're now an admin    Thursday  February
# 4      ‎Naa.... added Amogh Lumen, Chiranth Tgt Mar ...   Thursday  February
# ...                                                 ...        ...       ...
# 3457   Will share the emailid to the folks who fit t...  Wednesday       May
# 3458                         Location: Bangalore, Pune   Wednesday       May
# 3459                             Company: Epam systems   Wednesday       May
# 3460   Just answering the qs tht people are pinging ...  Wednesday       May
# 3461   ‎‪+91 75077 78670‬ joined using this group's ...  Wednesday       May
#
#       year hour
# 0     2023   15
# 1     2023   15
# 2     2023   16
# 3     2023   16
# 4     2023   17
# ...    ...  ...
# 3457  2023   13
# 3458  2023   14
# 3459  2023   14
# 3460  2023   14
# 3461  2023   14
#
# [3462 rows x 8 columns]

# %%
from datetime import datetime, date
clean_df.Time = clean_df.Time.apply(lambda x: datetime.strptime(x, '%H:%M'))
clean_df['hour'] = clean_df.Time.apply(lambda x: x.hour)

# %%
clean_df
# Out:
#            Date                Time                     Member  \
# 0    2023-02-08 1900-01-01 15:58:00   Top 1% Quality Engineers
# 1    2023-02-08 1900-01-01 15:58:00               Ayush Poddar
# 2    2023-02-09 1900-01-01 16:44:00   Top 1% Quality Engineers
# 3    2023-02-09 1900-01-01 16:44:00   Top 1% Quality Engineers
# 4    2023-02-09 1900-01-01 17:17:00   Top 1% Quality Engineers
# ...         ...                 ...                        ...
# 3457 2023-05-31 1900-01-01 13:58:00                    Naa....
# 3458 2023-05-31 1900-01-01 14:00:00                    Naa....
# 3459 2023-05-31 1900-01-01 14:01:00                    Naa....
# 3460 2023-05-31 1900-01-01 14:01:00                    Naa....
# 3461 2023-05-31 1900-01-01 14:47:00          ‪+91 75077 78670‬
#
#                                                 Message        day     month  \
# 0      ‎Messages and calls are end-to-end encrypted....  Wednesday  February
# 1                     ‎Ayush Poddar created this group   Wednesday  February
# 2                                   ‎Naa.... added you    Thursday  February
# 3                                 ‎You're now an admin    Thursday  February
# 4      ‎Naa.... added Amogh Lumen, Chiranth Tgt Mar ...   Thursday  February
# ...                                                 ...        ...       ...
# 3457   Will share the emailid to the folks who fit t...  Wednesday       May
# 3458                         Location: Bangalore, Pune   Wednesday       May
# 3459                             Company: Epam systems   Wednesday       May
# 3460   Just answering the qs tht people are pinging ...  Wednesday       May
# 3461   ‎‪+91 75077 78670‬ joined using this group's ...  Wednesday       May
#
#       year  hour
# 0     2023    15
# 1     2023    15
# 2     2023    16
# 3     2023    16
# 4     2023    17
# ...    ...   ...
# 3457  2023    13
# 3458  2023    14
# 3459  2023    14
# 3460  2023    14
# 3461  2023    14
#
# [3462 rows x 8 columns]

# %%
plt.figure(figsize = (10,6))
sns.countplot(x=clean_df['hour'])
plt.savefig('most_active_hour.png')

# %%
plt.figure(figsize = (10,6))
sns.countplot(x=clean_df['day'])
plt.savefig('most_active_day_of_week.png')

# %%
plt.figure(figsize = (10,6))
sns.countplot(x=clean_df['month'], hue = clean_df['day'])
plt.savefig('most_active_day_of_week_by_month.png')

# %%
from textblob import TextBlob

# %%
clean_df.iloc[0][3]
# Out:
# ' \u200eMessages and calls are end-to-end encrypted. No one outside of this chat, not even WhatsApp, can read or listen to them. '

# %%
clean_df['score'] = 0

# %%
polarity_score = []
for i in range(0,clean_df.shape[0]):
    score = TextBlob(clean_df.iloc[i][3])
    score1 = score.sentiment[0]
    polarity_score.append(score1)
    clean_df['score'][i] = score1

#concatenating the score with thw dataframe
# Out:
# <ipython-input-306-2abfc4265d92>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_df['score'][i] = score1

# %%
clean_df
# Out:
#            Date                Time                     Member  \
# 0    2023-02-08 1900-01-01 15:58:00   Top 1% Quality Engineers
# 1    2023-02-08 1900-01-01 15:58:00               Ayush Poddar
# 2    2023-02-09 1900-01-01 16:44:00   Top 1% Quality Engineers
# 3    2023-02-09 1900-01-01 16:44:00   Top 1% Quality Engineers
# 4    2023-02-09 1900-01-01 17:17:00   Top 1% Quality Engineers
# ...         ...                 ...                        ...
# 3457 2023-05-31 1900-01-01 13:58:00                    Naa....
# 3458 2023-05-31 1900-01-01 14:00:00                    Naa....
# 3459 2023-05-31 1900-01-01 14:01:00                    Naa....
# 3460 2023-05-31 1900-01-01 14:01:00                    Naa....
# 3461 2023-05-31 1900-01-01 14:47:00          ‪+91 75077 78670‬
#
#                                                 Message        day     month  \
# 0      ‎Messages and calls are end-to-end encrypted....  Wednesday  February
# 1                     ‎Ayush Poddar created this group   Wednesday  February
# 2                                   ‎Naa.... added you    Thursday  February
# 3                                 ‎You're now an admin    Thursday  February
# 4      ‎Naa.... added Amogh Lumen, Chiranth Tgt Mar ...   Thursday  February
# ...                                                 ...        ...       ...
# 3457   Will share the emailid to the folks who fit t...  Wednesday       May
# 3458                         Location: Bangalore, Pune   Wednesday       May
# 3459                             Company: Epam systems   Wednesday       May
# 3460   Just answering the qs tht people are pinging ...  Wednesday       May
# 3461   ‎‪+91 75077 78670‬ joined using this group's ...  Wednesday       May
#
#       year  hour  score
# 0     2023    15    0.0
# 1     2023    15    0.0
# 2     2023    16    0.0
# 3     2023    16    0.0
# 4     2023    17    0.0
# ...    ...   ...    ...
# 3457  2023    13    0.4
# 3458  2023    14    0.0
# 3459  2023    14    0.0
# 3460  2023    14    0.0
# 3461  2023    14    0.0
#
# [3462 rows x 9 columns]

# %%
#pos
len(clean_df[clean_df.score > 0])
# Out:
# 1093

# %%
print(clean_df[clean_df.score > 0])
# Out:
#            Date                Time              Member  \
# 6    2023-02-09 1900-01-01 17:19:00      ~ Harikrishnan
# 8    2023-02-09 1900-01-01 17:19:00    ~ Amit Kumar Jha
# 9    2023-02-09 1900-01-01 17:21:00    Vivian Tgt Sales
# 10   2023-02-09 1900-01-01 17:21:00             Naa....
# 11   2023-02-09 1900-01-01 17:22:00   ~ Praveen Singh V
# ...         ...                 ...                 ...
# 3453 2023-05-31 1900-01-01 13:54:00             Naa....
# 3454 2023-05-31 1900-01-01 13:55:00             Naa....
# 3455 2023-05-31 1900-01-01 13:56:00             Naa....
# 3456 2023-05-31 1900-01-01 13:56:00             Naa....
# 3457 2023-05-31 1900-01-01 13:58:00             Naa....
#
#                                                 Message        day     month  \
# 6                                        Thanks Reine,    Thursday  February
# 8                         Thanks Reine  Hello everyone    Thursday  February
# 9      Hi everyone, welcome to the Community of *Top...   Thursday  February
# 10     Hi, We are building a community of *"Top 1% o...   Thursday  February
# 11     Very warm welcome to all QA Professionals, th...   Thursday  February
# ...                                                 ...        ...       ...
# 3453   Very close friend of mine is hiring, Python a...  Wednesday       May
# 3454   JD as sent Very good experience on automation...  Wednesday       May
# 3455              If you fit the description please dm   Wednesday       May
# 3456   Ps: last time for the internship position loo...  Wednesday       May
# 3457   Will share the emailid to the folks who fit t...  Wednesday       May
#
#       year  hour     score
# 6     2023    17  0.200000
# 8     2023    17  0.200000
# 9     2023    17  0.516667
# 10    2023    17  0.239286
# 11    2023    17  0.790000
# ...    ...   ...       ...
# 3453  2023    13  0.200000
# 3454  2023    13  0.577500
# 3455  2023    13  0.400000
# 3456  2023    13  0.250000
# 3457  2023    13  0.400000
#
# [1093 rows x 9 columns]

# %%
print(clean_df[10:11]['Message'].item())
# Out:
#  Hi, We are building a community of *"Top 1% of QA Engineers*". The entire idea is to enable QA engineers have the right growth awareness, build on their potential skills, get into their dream job and achieve highest packages in QA Vertical (which is 50L+). If you are interested to join our community, please click on the link below and join… https://chat.whatsapp.com/FHmw3F7qPWt3jAzKUOrUoF  We would also be encouraging interactions and  posting relevant content, articles, videos, scholarships, jobs, and hosting events from QA Leaders, Engineering Heads and Project Heads in the Community.  _Looking forward to see you there._

# %%
#neg
len(clean_df[clean_df.score < 0])
# Out:
# 132

# %%
#nut
len(clean_df[clean_df.score == 0])
# Out:
# 2237

# %%
#creating a new column to label the sentiment
import numpy as np
filters = [
   (clean_df.score > 0) ,
   (clean_df.score < 0) ,
   (clean_df.score == 0)
]
values = ["Positive", "Negative", "Neutral"]

clean_df["status"] = np.select(filters, values)
clean_df.tail()
# Out:
#            Date                Time              Member  \
# 3457 2023-05-31 1900-01-01 13:58:00             Naa....
# 3458 2023-05-31 1900-01-01 14:00:00             Naa....
# 3459 2023-05-31 1900-01-01 14:01:00             Naa....
# 3460 2023-05-31 1900-01-01 14:01:00             Naa....
# 3461 2023-05-31 1900-01-01 14:47:00   ‪+91 75077 78670‬
#
#                                                 Message        day month  \
# 3457   Will share the emailid to the folks who fit t...  Wednesday   May
# 3458                         Location: Bangalore, Pune   Wednesday   May
# 3459                             Company: Epam systems   Wednesday   May
# 3460   Just answering the qs tht people are pinging ...  Wednesday   May
# 3461   ‎‪+91 75077 78670‬ joined using this group's ...  Wednesday   May
#
#       year  hour  score    status
# 3457  2023    13    0.4  Positive
# 3458  2023    14    0.0   Neutral
# 3459  2023    14    0.0   Neutral
# 3460  2023    14    0.0   Neutral
# 3461  2023    14    0.0   Neutral

# %%
count = clean_df['status'].value_counts()
#Using matplotlib donught chart
plt.pie(count, labels = count.index,autopct='%.0f%%',startangle = 90,
        counterclock = False);
plt.title('Message sentiment');
plt.savefig('all_messages_sentiment.png')

# %%
count
# Out:
# Neutral     2237
# Positive    1093
# Negative     132
# Name: status, dtype: int64

# %% [markdown]
# **Why people left**

# %%
final_df_copy_=final_df.copy()

# %%
final_df
# Out:
#           Date         Time                     Member  \
# 0     08/02/23   3:58:37 PM   Top 1% Quality Engineers
# 1     08/02/23   3:58:37 PM               Ayush Poddar
# 2     09/02/23   4:44:34 PM   Top 1% Quality Engineers
# 3     09/02/23   4:44:40 PM   Top 1% Quality Engineers
# 4     09/02/23   5:17:49 PM   Top 1% Quality Engineers
# ...        ...          ...                        ...
# 3675  31/05/23   1:58:17 PM                    Naa....
# 3676  31/05/23   2:00:53 PM                    Naa....
# 3677  31/05/23   2:01:05 PM                    Naa....
# 3678  31/05/23   2:01:33 PM                    Naa....
# 3679  31/05/23   2:47:42 PM          ‪+91 75077 78670‬
#
#                                                 Message
# 0      ‎Messages and calls are end-to-end encrypted....
# 1                     ‎Ayush Poddar created this group
# 2                                   ‎Naa.... added you
# 3                                 ‎You're now an admin
# 4      ‎Naa.... added Amogh Lumen, Chiranth Tgt Mar ...
# ...                                                 ...
# 3675   Will share the emailid to the folks who fit t...
# 3676                         Location: Bangalore, Pune
# 3677                             Company: Epam systems
# 3678   Just answering the qs tht people are pinging ...
# 3679   ‎‪+91 75077 78670‬ joined using this group's ...
#
# [3680 rows x 4 columns]

# %%
final_df
# Out:
#           Date         Time                     Member  \
# 0     08/02/23   3:58:37 PM   Top 1% Quality Engineers
# 1     08/02/23   3:58:37 PM               Ayush Poddar
# 2     09/02/23   4:44:34 PM   Top 1% Quality Engineers
# 3     09/02/23   4:44:40 PM   Top 1% Quality Engineers
# 4     09/02/23   5:17:49 PM   Top 1% Quality Engineers
# ...        ...          ...                        ...
# 3675  31/05/23   1:58:17 PM                    Naa....
# 3676  31/05/23   2:00:53 PM                    Naa....
# 3677  31/05/23   2:01:05 PM                    Naa....
# 3678  31/05/23   2:01:33 PM                    Naa....
# 3679  31/05/23   2:47:42 PM          ‪+91 75077 78670‬
#
#                                                 Message
# 0      ‎Messages and calls are end-to-end encrypted....
# 1                     ‎Ayush Poddar created this group
# 2                                   ‎Naa.... added you
# 3                                 ‎You're now an admin
# 4      ‎Naa.... added Amogh Lumen, Chiranth Tgt Mar ...
# ...                                                 ...
# 3675   Will share the emailid to the folks who fit t...
# 3676                         Location: Bangalore, Pune
# 3677                             Company: Epam systems
# 3678   Just answering the qs tht people are pinging ...
# 3679   ‎‪+91 75077 78670‬ joined using this group's ...
#
# [3680 rows x 4 columns]

# %%
all_left = []
lennn=[]


for num in range(len(final_df)):
  ax=final_df['Message'][num:num+1]
  txt=ax.item()
  try:
    x = txt.find("left")
    if x != -1:
      all_left.append(final_df['Member'][num:num+1])

  except:
    print()

# %%
len(all_left)
# Out:
# 223

# %%
all_left
# Out:
# [48     Nagesh Eraiah Ctl
#  Name: Member, dtype: object,
#  51     Ritu Ibm
#  Name: Member, dtype: object,
#  60     Ritu Ibm
#  Name: Member, dtype: object,
#  78     Malar Vendhan
#  Name: Member, dtype: object,
#  81     Cinoy Ctli
#  Name: Member, dtype: object,
#  97     Ratna Arepalli
#  Name: Member, dtype: object,
#  105     Shalini Bandari
#  Name: Member, dtype: object,
#  130     ‪+91 99458 25692‬
#  Name: Member, dtype: object,
#  154     ‪+91 78895 64215‬
#  Name: Member, dtype: object,
#  189     ‪+91 94491 61646‬
#  Name: Member, dtype: object,
#  190     ‪+91 97427 72747‬
#  Name: Member, dtype: object,
#  207     ‪+91 70101 39909‬
#  Name: Member, dtype: object,
#  247     ‪+91 89561 63419‬
#  Name: Member, dtype: object,
#  254     ‪+374 55 105040‬
#  Name: Member, dtype: object,
#  294     Sumit Ghosh Ctl
#  Name: Member, dtype: object,
#  307     ‪+48 600 763 839‬
#  Name: Member, dtype: object,
#  330     Aboli Tgt Mar 2023
#  Name: Member, dtype: object,
#  367     ~ Qadeer Ahmed
#  Name: Member, dtype: object,
#  381     ~ A
#  Name: Member, dtype: object,
#  394     ~ Malla Manikantha
#  Name: Member, dtype: object,
#  446     ‪+91 80879 48455‬
#  Name: Member, dtype: object,
#  447     ~ PG
#  Name: Member, dtype: object,
#  453     ‪+39 334 654 2214‬
#  Name: Member, dtype: object,
#  469     ‪+91 83089 32844‬
#  Name: Member, dtype: object,
#  477     ~ Sam
#  Name: Member, dtype: object,
#  499     ~ Sushma
#  Name: Member, dtype: object,
#  528     ‪+91 99620 71007‬
#  Name: Member, dtype: object,
#  566     ~ Sushant Kulkarni
#  Name: Member, dtype: object,
#  567     ~ Padmavati G A
#  Name: Member, dtype: object,
#  603     ‪+44 7432 098300‬
#  Name: Member, dtype: object,
#  705     ‪+91 84580 40223‬
#  Name: Member, dtype: object,
#  706     ~ G@₹!M@ $H@₹M@
#  Name: Member, dtype: object,
#  785     ‪+1 (984) 286‑3320‬
#  Name: Member, dtype: object,
#  786     Naa....
#  Name: Member, dtype: object,
#  801     ‪+91 99869 42000‬
#  Name: Member, dtype: object,
#  802     ~ Ashish Ahuja
#  Name: Member, dtype: object,
#  817     ~ indrajitdey226
#  Name: Member, dtype: object,
#  821     ~ Rakesh Yadav
#  Name: Member, dtype: object,
#  866     ~ Ankit
#  Name: Member, dtype: object,
#  889     ‪+91 70783 83079‬
#  Name: Member, dtype: object,
#  925     ‪+91 87007 48363‬
#  Name: Member, dtype: object,
#  1046     ‪+91 76670 21535‬
#  Name: Member, dtype: object,
#  1047     ‪+91 80738 88146‬
#  Name: Member, dtype: object,
#  1056     ~ Saba Shahin
#  Name: Member, dtype: object,
#  1063     ~ Prashanth
#  Name: Member, dtype: object,
#  1069     ‪+91 84979 56893‬
#  Name: Member, dtype: object,
#  1083     ‪+91 88615 98986‬
#  Name: Member, dtype: object,
#  1084     ‪+91 97008 70615‬
#  Name: Member, dtype: object,
#  1086     ~ Rahul🤫
#  Name: Member, dtype: object,
#  1087     ~ Pavan
#  Name: Member, dtype: object,
#  1094     ‪+91 98706 26565‬
#  Name: Member, dtype: object,
#  1096     ~ 🕉️
#  Name: Member, dtype: object,
#  1106     ‪+91 78750 21692‬
#  Name: Member, dtype: object,
#  1144     ~ Kamaraj Sadhasivam
#  Name: Member, dtype: object,
#  1146     ~ parshukobe841
#  Name: Member, dtype: object,
#  1163     ~ Suresh Gowda
#  Name: Member, dtype: object,
#  1164     ~ .
#  Name: Member, dtype: object,
#  1165     ‪+380 50 025 7069‬
#  Name: Member, dtype: object,
#  1172     ‪+91 93013 16173‬
#  Name: Member, dtype: object,
#  1217     Hemapriya Ctl
#  Name: Member, dtype: object,
#  1241     ‪+91 99516 48644‬
#  Name: Member, dtype: object,
#  1265     ‪+91 88882 31833‬
#  Name: Member, dtype: object,
#  1286     ~ Arati♥️
#  Name: Member, dtype: object,
#  1304     ‪+91 76761 89574‬
#  Name: Member, dtype: object,
#  1305     ‪+91 96295 31833‬
#  Name: Member, dtype: object,
#  1306     ‪+91 98403 12498‬
#  Name: Member, dtype: object,
#  1328     ~ Deek
#  Name: Member, dtype: object,
#  1342     ‪+91 83740 90572‬
#  Name: Member, dtype: object,
#  1348     ‪+91 88793 85297‬
#  Name: Member, dtype: object,
#  1376     ‪+91 90003 36915‬
#  Name: Member, dtype: object,
#  1390     ‪+91 72995 67080‬
#  Name: Member, dtype: object,
#  1411     ‪+91 98411 48212‬
#  Name: Member, dtype: object,
#  1441     ~ Vasu
#  Name: Member, dtype: object,
#  1442     ‪+91 90427 20503‬
#  Name: Member, dtype: object,
#  1465     ‪+91 70572 01332‬
#  Name: Member, dtype: object,
#  1469     ‪+91 81948 39291‬
#  Name: Member, dtype: object,
#  1472     ~ RM
#  Name: Member, dtype: object,
#  1482     ~ SARA ❤️
#  Name: Member, dtype: object,
#  1519     ‪+91 99852 90108‬
#  Name: Member, dtype: object,
#  1541     ‪+91 84779 42894‬
#  Name: Member, dtype: object,
#  1542     ~ Preeti
#  Name: Member, dtype: object,
#  1570     ‪+91 99231 14200‬
#  Name: Member, dtype: object,
#  1572     ~ PudariAnjagoud🏏
#  Name: Member, dtype: object,
#  1576     ‪+91 78999 61747‬
#  Name: Member, dtype: object,
#  1583     ‪+91 73582 82745‬
#  Name: Member, dtype: object,
#  1620     ‪+91 96636 15760‬
#  Name: Member, dtype: object,
#  1624     ‪+91 74707 12139‬
#  Name: Member, dtype: object,
#  1625     Balaji Uni
#  Name: Member, dtype: object,
#  1626     ‪+91 88011 51051‬
#  Name: Member, dtype: object,
#  1656     ‪+91 95720 33925‬
#  Name: Member, dtype: object,
#  1673     ‪+91 72044 75330‬
#  Name: Member, dtype: object,
#  1674     ~ varsha singh
#  Name: Member, dtype: object,
#  1695     ‪+91 91 82225 074‬
#  Name: Member, dtype: object,
#  1703     ~ Diwakar Jaiswal
#  Name: Member, dtype: object,
#  1705     ~ Tej.
#  Name: Member, dtype: object,
#  1707     ~ Manoj
#  Name: Member, dtype: object,
#  1735     ‪+91 82107 01966‬
#  Name: Member, dtype: object,
#  1736     ‪+91 79810 10050‬
#  Name: Member, dtype: object,
#  1742     ~ Tamil
#  Name: Member, dtype: object,
#  1745     ‪+91 80768 47357‬
#  Name: Member, dtype: object,
#  1752     ~ .
#  Name: Member, dtype: object,
#  1766     ‪+91 87926 41417‬
#  Name: Member, dtype: object,
#  1775     ‪+91 97406 56673‬
#  Name: Member, dtype: object,
#  1776     ‪+91 96404 05995‬
#  Name: Member, dtype: object,
#  1787     ‪+91 99164 74893‬
#  Name: Member, dtype: object,
#  1848     ~ Netra
#  Name: Member, dtype: object,
#  1858     ~ Megha Kk
#  Name: Member, dtype: object,
#  1861     ‪+91 81442 39367‬
#  Name: Member, dtype: object,
#  1866     ~ Shivaprasad C N
#  Name: Member, dtype: object,
#  1877     ‪+91 81208 36724‬
#  Name: Member, dtype: object,
#  1886     Ravindra Ctl
#  Name: Member, dtype: object,
#  1907     ‪+91 99620 23700‬
#  Name: Member, dtype: object,
#  1928     ~ Neetu Jha
#  Name: Member, dtype: object,
#  1940     ~ Jaffar Lone
#  Name: Member, dtype: object,
#  1953     ‪+91 94928 36051‬
#  Name: Member, dtype: object,
#  1977     ~ Keval
#  Name: Member, dtype: object,
#  1981     ‪+91 99231 06450‬
#  Name: Member, dtype: object,
#  1992     ‪+91 96895 46655‬
#  Name: Member, dtype: object,
#  2025     ‪+91 98441 15703‬
#  Name: Member, dtype: object,
#  2057     ‪+91 98402 18536‬
#  Name: Member, dtype: object,
#  2076     ~ ItsSP
#  Name: Member, dtype: object,
#  2077     ~ itsfarooqnaeem
#  Name: Member, dtype: object,
#  2096     ~ विशाल सुरसे
#  Name: Member, dtype: object,
#  2097     ~ vikashpawan941
#  Name: Member, dtype: object,
#  2107     ~ Susmita
#  Name: Member, dtype: object,
#  2108     ‪+91 76928 07667‬
#  Name: Member, dtype: object,
#  2109     ‪+91 98338 77987‬
#  Name: Member, dtype: object,
#  2112     ~ sirisha
#  Name: Member, dtype: object,
#  2129     ‪+91 94489 57973‬
#  Name: Member, dtype: object,
#  2135     ‪+91 99636 31617‬
#  Name: Member, dtype: object,
#  2164     ‪+91 91 6491 180 0‬
#  Name: Member, dtype: object,
#  2171     ~ ༺ċhändü♥️röÿäls༻
#  Name: Member, dtype: object,
#  2172     ~ @Prince*Jaik
#  Name: Member, dtype: object,
#  2185     ~ Navee😍
#  Name: Member, dtype: object,
#  2187     ~ Teju
#  Name: Member, dtype: object,
#  2188     ~ ur___cpu__🥀
#  Name: Member, dtype: object,
#  2243     ~ Ranjana
#  Name: Member, dtype: object,
#  2244     ‪+91 73491 34964‬
#  Name: Member, dtype: object,
#  2253     ~ Ravindra Jain
#  Name: Member, dtype: object,
#  2254     ‪+91 95525 88556‬
#  Name: Member, dtype: object,
#  2257     ~ Kamaraj Sadhasivam
#  Name: Member, dtype: object,
#  2288     ~ Vandana Amarnath😇
#  Name: Member, dtype: object,
#  2353     ~ Jonu
#  Name: Member, dtype: object,
#  2381     ~ Brahmo
#  Name: Member, dtype: object,
#  2383     ~ Vidya💞Preethu
#  Name: Member, dtype: object,
#  2394     ~ Vikash Kumar
#  Name: Member, dtype: object,
#  2421     ~ ♟️
#  Name: Member, dtype: object,
#  2427     ‪+91 78293 70999‬
#  Name: Member, dtype: object,
#  2470     ‪+91 77570 46340‬
#  Name: Member, dtype: object,
#  2496     ‪+91 98733 03877‬
#  Name: Member, dtype: object,
#  2497     ~ Girish Nagrale
#  Name: Member, dtype: object,
#  2513     ‪+91 79757 11648‬
#  Name: Member, dtype: object,
#  2523     ~ Arunshi
#  Name: Member, dtype: object,
#  2550     ‪+91 87544 83307‬
#  Name: Member, dtype: object,
#  2551     ~ Mythili ❤️
#  Name: Member, dtype: object,
#  2553     ‪+91 97517 94600‬
#  Name: Member, dtype: object,
#  2582     ‪+91 90355 49356‬
#  Name: Member, dtype: object,
#  2597     ‪+91 99410 10666‬
#  Name: Member, dtype: object,
#  2645     ~ Zero Floor
#  Name: Member, dtype: object,
#  2652     ‪+91 98883 02663‬
#  Name: Member, dtype: object,
#  2665     ~ shree
#  Name: Member, dtype: object,
#  2666     ~ Nikhil Padliya
#  Name: Member, dtype: object,
#  2698     ~ Ravi
#  Name: Member, dtype: object,
#  2699     ~ Unknown 😊
#  Name: Member, dtype: object,
#  2734     ‪+91 91 0 84482 81‬
#  Name: Member, dtype: object,
#  2746     ~ Praveen Singh V
#  Name: Member, dtype: object,
#  2762     ~ Ishwaragouda M
#  Name: Member, dtype: object,
#  2775     ‪+91 89200 51925‬
#  Name: Member, dtype: object,
#  2780     ~ Purnima
#  Name: Member, dtype: object,
#  2782     ~ Suganthi Jayaraj
#  Name: Member, dtype: object,
#  2794     ~ mainak
#  Name: Member, dtype: object,
#  2798     ‪+91 96593 87237‬
#  Name: Member, dtype: object,
#  2833     ~ Saral Rizwana
#  Name: Member, dtype: object,
#  2877     Lavanya Gutta Ctli
#  Name: Member, dtype: object,
#  2882     ~ Shreehari Upadhyaya
#  Name: Member, dtype: object,
#  2887     ~ PradyumnaBiswal
#  Name: Member, dtype: object,
#  2914     ‪+91 93407 59963‬
#  Name: Member, dtype: object,
#  2939     ‪+91 77806 53310‬
#  Name: Member, dtype: object,
#  2980     ~ Aparna
#  Name: Member, dtype: object,
#  3014     ‪+91 94907 24987‬
#  Name: Member, dtype: object,
#  3019     ‪+91 86057 63358‬
#  Name: Member, dtype: object,
#  3060     ~ Parag
#  Name: Member, dtype: object,
#  3090     Pratim Ghoshal Ctl
#  Name: Member, dtype: object,
#  3131     ~ Pramod Pallath
#  Name: Member, dtype: object,
#  3136     ‪+91 95578 75918‬
#  Name: Member, dtype: object,
#  3150     ‪+91 97411 79892‬
#  Name: Member, dtype: object,
#  3152     ~ Gautham Raj R
#  Name: Member, dtype: object,
#  3241     ~ Anjali Mittal
#  Name: Member, dtype: object,
#  3254     ~ Abhijack
#  Name: Member, dtype: object,
#  3263     ~ ravi teja
#  Name: Member, dtype: object,
#  3269     ~ vins👻
#  Name: Member, dtype: object,
#  3272     ‪+91 88611 59292‬
#  Name: Member, dtype: object,
#  3373     ‪+91 98864 12725‬
#  Name: Member, dtype: object,
#  3390     ~ Sasikumar S
#  Name: Member, dtype: object,
#  3481     ~ Haribabu
#  Name: Member, dtype: object,
#  3485     ‪+91 89713 00223‬
#  Name: Member, dtype: object,
#  3489     ‪+91 83092 34652‬
#  Name: Member, dtype: object,
#  3513     ‪+91 89711 98601‬
#  Name: Member, dtype: object,
#  3541     ‪+91 95519 69696‬
#  Name: Member, dtype: object,
#  3552     ‪+91 77605 95650‬
#  Name: Member, dtype: object,
#  3555     ~ Jennifer(Jenny)
#  Name: Member, dtype: object,
#  3611     ‪+91 82774 96764‬
#  Name: Member, dtype: object,
#  3614     ~ Anupama
#  Name: Member, dtype: object,
#  3615     ~ @
#  Name: Member, dtype: object,
#  3646     ‪+91 98947 07617‬
#  Name: Member, dtype: object,
#  3647     ~ Nikita Patil
#  Name: Member, dtype: object,
#  3648     ‪+91 99800 26460‬
#  Name: Member, dtype: object,
#  3649     ‪+91 98600 07032‬
#  Name: Member, dtype: object,
#  3650     ~ Siddesh S
#  Name: Member, dtype: object,
#  3653     ~ Bhavana
#  Name: Member, dtype: object,
#  3654     ~ Govindh
#  Name: Member, dtype: object,
#  3655     ~ ncvoleti
#  Name: Member, dtype: object,
#  3656     ~ Ritu
#  Name: Member, dtype: object,
#  3657     ~ Aloke
#  Name: Member, dtype: object,
#  3658     ~ Gireesh
#  Name: Member, dtype: object,
#  3659     ‪+91 98454 36907‬
#  Name: Member, dtype: object,
#  3660     ~ swara🎃
#  Name: Member, dtype: object,
#  3661     ~ KK😎
#  Name: Member, dtype: object,
#  3662     ‪+91 97399 69475‬
#  Name: Member, dtype: object,
#  3663     ~ Sanket Joshi
#  Name: Member, dtype: object,
#  3664     ~ RohithGundra
#  Name: Member, dtype: object,
#  3665     ‪+91 93819 56708‬
#  Name: Member, dtype: object,
#  3667     ~ Anusha
#  Name: Member, dtype: object]

# %%
message=[]

for i in range(len(all_left)):
  temp_memb = all_left[i].item()

  for num in range(len(final_df)):
    ax=final_df['Member'][num:num+1]
    txt=ax.item()
    txt=str(txt)
    try:
      x = txt.find(temp_memb)
      if x != -1:
        mess=final_df['Message'][num:num+1]
        temp_mess = mess.item()
        message.append(temp_mess)
    except:
      print()

# %%
len(message)
# Out:
# 1233

# %%
my_list = message
single_string = ' '.join([str(item) if item is not None else '' for item in my_list])
print(single_string)
# Out:
#  ‎Nagesh Eraiah Ctl left   ‎Ritu Ibm left   ‎Ritu Ibm was added   Apologies, I am still not sure of the objective of this group, Can someone pls help to understand.   Thanks Ayush, my bad, I didn't read the group description   ‎Ritu Ibm left   ‎Ritu Ibm left   ‎Ritu Ibm was added   Apologies, I am still not sure of the objective of this group, Can someone pls help to understand.   Thanks Ayush, my bad, I didn't read the group description   ‎Ritu Ibm left   ‎Malar Vendhan left   ‎Cinoy Ctli left   ‎You added Cinoy Ctli   ‎Ratna Arepalli left   Hi Myself Shalini Bandari, with 8 + years of experience in industrial automation and Testing and project management, currently in a break due to kid waiting for an Oppurtunity to start my career   ‎Shalini Bandari left   ‎Naa.... added ‪+91 99458 25692‬   ‎‪+91 99458 25692‬ left   ‎‪+91 78895 64215‬ joined using this group's invite link   ‎‪+91 78895 64215‬ left   ‎‪+91 94491 61646‬ left   ‎‪+91 97427 72747‬ left   ‎‪+91 70101 39909‬ left   ‎‪+91 89561 63419‬ joined using this group's invite link   ‎‪+91 89561 63419‬ left   ‎‪+374 55 105040‬ joined using this group's invite link   ‎‪+374 55 105040‬ left   ‎Sumit Ghosh Ctl left   ‎‪+48 600 763 839‬ joined using this group's invite link   ‎‪+48 600 763 839‬ left   ‎Aboli Tgt Mar 2023 joined using this group's invite link   ‎Aboli Tgt Mar 2023 left   ‎Aboli Tgt Mar 2023 joined using this group's invite link   ‎‎Your security code with Aboli changed. ‎Tap to learn more.   ‎~ Qadeer Ahmed joined using this group's invite link   ‎~ Qadeer Ahmed left   Thanks Reine  Hello everyone   ‎~ Asha Govindaraju joined using this group's invite link   Registered my self @919449031578 , received email to join the event   ‎~ Aloke joined using this group's invite link   ‎~ Archana joined using this group's invite link   ‎~ Atif Iqubal joined using this group's invite link   ‎~ Ashish Ahuja joined using this group's invite link   Hello Everyone,  I am Ashish Ahuja working as a Senior QA Engineer with Shoptrue Inc (a US based start-up). I have total 8+ years of experience in product testing + automation (Selenium, API with Python + BDD).  Glad to be a part of this community, looking forward to learn and grow along with everyone.   ‎~ Ankit joined using this group's invite link   Registered 👍   Hi Ankit Here, I'm SDET II with around 9 years exp. I want to know how to move forward in this domain without moving to Lead or management role. I want to proceed in tech maybe like QA Architect or something. Haven't seen many roles like this and mostly people go towards management side or they change to dev or ba from what i have seen in my experience.   Thanks I've registered already   ‎~ Abha Dangarikar joined using this group's invite link   Hello Everyone myself Abha Dangarikar currently am a housewife , prior to this I had 14th yrs of IT experience  Now I am looking for work for home jobs   👍🏻   ‎~ Asad joined using this group's invite link   ‎~ A joined using this group's invite link   ‎~ A left   ‎~ Alok Kumar joined using this group's invite link   I am a job seeker looking for job in Software testing   ‎~ Anu joined using this group's invite link   Hi everyone , my name is Anushya from Computer science background, i have completed  java fullstack web development course recently. and i am looking for a job as a Backend java developer   ‎~ Abhijack joined using this group's invite link   ‎~ AK joined using this group's invite link   @918790909745  can you please share the link   I am Arun working in FIS as Senior QA Manager   ‎~ Aarthi joined using this group's invite link   That's why we need such community to build and help each other   This meeting concluded yesterday itself   DM you   Hi All,  I was working o my LinkedIn profile since 2 days here is the profile https://www.linkedin.com/in/aashu24ahuja/ would love to hear feedback/suggestions.   sure, noted.   yes just did   I have already registered but still asking to register   And not received this link i ...

# %%
#if len(single_string) == 0 :

# %%
from PIL import Image, ImageDraw, ImageFont

# Create a blank image with the desired size and background color
width, height = 1600, 800
background_color = (255, 255, 255)  # RGB color values for white
image = Image.new('RGB', (width, height), background_color)

# Create a drawing object
draw = ImageDraw.Draw(image)

# Specify the text and font properties
text = 'Word Cloud not possible'
font_size = 100
font = ImageFont.truetype('arial.ttf', font_size)

# Calculate the size of the text
text_width, text_height = draw.textsize(text, font=font)

# Calculate the position to center the text
x = (width - text_width) // 2
y = (height - text_height) // 2

# Draw the text on the image
draw.text((x, y), text, font=font, fill=(0, 0, 0))  # RGB color values for black
image.show()
# Save the image to a file
image.save('output.png')
# Out:
# <PIL.Image.Image image mode=RGB size=1600x800 at 0x7F555C6D7640>

# %%
#text = " ".join(i for i in clean_df['Message'])
#stopwords = set(STOPWORDS)
wordcloud = WordCloud(width=1600, height=800).generate(single_string)
plt.figure( figsize=(20,10), facecolor='k')
plt.imshow(wordcloud)
plt.axis("off")
plt.savefig('wordcloud.png', facecolor='k', bbox_inches='tight')
#plt.tight_layout(pad=0)
plt.show()
#plt.savefig('wordcloud.pdf')
#wordcloud.to_file('wordcloud.png')
plt.clf()

# %%
why_left = []
for left_l in range(len(all_left)):
  for num in range(len(final_df)):
    ax=final_df['Member'][num:num+1]
    ax=ax.item()
    x = ax.find(all_left[left_l].replace(' left ', ''))
    if x != -1:
      why_left.append(str(final_df['Message'][num:num+1]))


    #if ax == all_left[left_l].replace('left', ' '):

      ##why_left.append(final_df['Message'][num:num+1])
      #print(final_df['Message'][num:num+1])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-328-3f3f17bdb341> in <cell line: 2>()
#       4     ax=final_df['Member'][num:num+1]
#       5     ax=ax.item()
# ----> 6     x = ax.find(all_left[left_l].replace(' left ', ''))
#       7     if x != -1:
#       8       why_left.append(str(final_df['Message'][num:num+1]))
#
# TypeError: must be str, not Series

# %%
len(why_left)

# %%
why_left = []
for left_l in range(len(all_left)):
  for num in range(len(final_df)):
    ax=final_df['Member'][num:num+1]
    ax=ax.item()
    x = ax.find(all_left[left_l].replace(' left ', ''))
    if x != -1:
      if final_df['Message'][num:num+1].item() == None :
        why_left.append(final_df['Message'][num-1:num])
      else:
        why_left.append(str(final_df['Message'][num:num+1]))


    #if ax == all_left[left_l].replace('left', ' '):

      ##why_left.append(final_df['Message'][num:num+1])
      #print(final_df['Message'][num:num+1])

# %%
why_left

# %%
polarity_score = []
for i in range(len(message)):
  txt = message[i]
  score = TextBlob(txt)
  score1 = score.sentiment[0]
  polarity_score.append(score1)

# %%
polarity_score

# %%
polarity_score = pd.DataFrame(polarity_score, columns=['score'])

# %%
filters = [
   (polarity_score.score > 0) ,
   (polarity_score.score < 0) ,
   (polarity_score.score == 0)
]
values = ["Positive", "Negative", "Neutral"]

polarity_score["status"] = np.select(filters, values)

# %%
count = polarity_score['status'].value_counts()
#Using matplotlib donught chart
plt.pie(count, labels = count.index,autopct='%.0f%%',startangle = 90, counterclock = False);
plt.title('People who left their sentiment');
plt.savefig('People_who_left_their_sentiment.png')
plt.show()

# %%
polarity_score
# Out:
#       score    status
# 0     0.000   Neutral
# 1     0.000   Neutral
# 2     0.000   Neutral
# 3    -0.125  Negative
# 4    -0.250  Negative
# ...     ...       ...
# 1228  0.000   Neutral
# 1229  0.000   Neutral
# 1230  0.000   Neutral
# 1231  0.000   Neutral
# 1232  0.000   Neutral
#
# [1233 rows x 2 columns]

# %%
len(message)
polarity_score['message']=message

# %%
polarity_score
# Out:
#       score    status                                            message
# 0     0.000   Neutral                           ‎Nagesh Eraiah Ctl left
# 1     0.000   Neutral                                    ‎Ritu Ibm left
# 2     0.000   Neutral                               ‎Ritu Ibm was added
# 3    -0.125  Negative   Apologies, I am still not sure of the objecti...
# 4    -0.250  Negative   Thanks Ayush, my bad, I didn't read the group...
# ...     ...       ...                                                ...
# 1228  0.000   Neutral                           ‎‪+91 93819 56708‬ left
# 1229  0.000   Neutral   ‎~ Anusha joined using this group's invite link
# 1230  0.000   Neutral                                    ‎image omitted
# 1231  0.000   Neutral                                               Yes
# 1232  0.000   Neutral                                    ‎~ Anusha left
#
# [1233 rows x 3 columns]

# %%
neg_message=[]
for i in range(len(polarity_score['status'])):

  x = polarity_score[i:i+1]['status'].item()
  if x == 'Negative':
    neg_message.append(polarity_score[i:i+1]['message'].item())

# %%
neg_message

# %%
neg_message = pd.DataFrame(neg_message)

# Save DataFrame as CSV
df.to_csv('neg_message.csv', index=False)

# %%
neg_message
# Out:
#                                                     0
# 0    Apologies, I am still not sure of the objecti...
# 1    Thanks Ayush, my bad, I didn't read the group...
# 2    Apologies, I am still not sure of the objecti...
# 3    Thanks Ayush, my bad, I didn't read the group...
# 4    Hi Myself Shalini Bandari, with 8 + years of ...
# 5    That's why we need such community to build an...
# 6    The major difficulty in today is *Recession* ...
# 7    Hai myself ajithkumar.i am a junior test engi...
# 8    I'm not able to see the old messages in hirin...
# 9    Very simple process to go ahead-  everyday sp...
# 10   On weekends spend 1-2 hour rerun & revisit  y...
# 11   There are few companies that take resources e...
# 12   That I will suggest better learn to handle be...
# 13   Anybody please give some inputs how to get re...
# 14   Yes. I'm getting call for working from office...
# 15   Yes I'm getting very few opportunities for wo...
# 16   How to find remote jobs from any product base...
# 17   Sorry for confusion i am seeking this positio...
# 18   I should add, no charges, of course. We forme...
# 19   Hi guys, I am planning an online event on the...
# 20                              Do you mean edit it?
# 21   Yes just like how user stories can be written...
# 22         Sorry moving the messages to hiring group
# 23   Hello everyone, apologies to everyone who reg...
# 24   The material is paid (we can’t into their bad...
# 25   As said above, I have around 17 years of expe...
# 26                                Sorry wrongly send
# 27             why did you change job(s) previously.
# 28   https://www.close.com/ is recruiting automati...
# 29   Majorly some time of nervousness.. So sometim...
# 30   We used to do that and from our experience it...
# 31   Or is your assumption that its biased bexause...
# 32   Remote QA job. You can apply dorectly using b...
# 33   Yes I am getting a few calls but the number b...
# 34   ‎~ Unknown 😊 joined using this group's invite...
# 35                                 ‎~ Unknown 😊 left
# 36   ‎POLL: Freshers skills not up to mark ‎OPTION...
# 37   System Testing tests the entire product or se...
# 38                       This is remote opportunity?
# 39   Recently in our API testing project there is ...
# 40          agree with this, not a great pay in BA's
# 41   Due to the current situation of layoffs in th...

# %%
neg_message

# %%
count

# %%
len(clean_df['Member'].unique())
